# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
md_df = pd.DataFrame.from_csv('data/mouse_drug_data.csv')
ct_df = pd.DataFrame.from_csv('data/clinicaltrial_data.csv')

# Combine the data into a single dataset
df = pd.merge(md_df,ct_df, on='Mouse ID')

# Display the data table for preview
df
# Out:
#               Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# f234      Stelasyn          0           45.000000                 0
# f234      Stelasyn          5           47.313491                 0
# f234      Stelasyn         10           47.904324                 0
# f234      Stelasyn         15           48.735197                 1
# f234      Stelasyn         20           51.112713                 2
# f234      Stelasyn         25           52.178602                 2
# f234      Stelasyn         30           56.873817                 2
# f234      Stelasyn         35           57.748758                 2
# x402      Stelasyn          0           45.000000                 0
# x402      Stelasyn          5           46.327570                 1
# x402      Stelasyn         10           46.886962                 1
# x402      Stelasyn         15           49.119948                 1
# x402      Stelasyn         20           50.414750                 2
# ...

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
mtv_df_mi = pd.DataFrame({'Mean Tumor Volume (mm3)' : df.groupby(['Drug', 'Timepoint'])['Tumor Volume (mm3)'].mean()})

# Preview DataFrame
mtv_df = mtv_df_mi.reset_index()

mtv_df
# Out:
#          Drug  Timepoint  Mean Tumor Volume (mm3)
# 0   Capomulin          0                45.000000
# 1   Capomulin          5                44.266086
# 2   Capomulin         10                43.084291
# 3   Capomulin         15                42.064317
# 4   Capomulin         20                40.716325
# 5   Capomulin         25                39.939528
# 6   Capomulin         30                38.769339
# 7   Capomulin         35                37.816839
# 8   Capomulin         40                36.958001
# 9   Capomulin         45                36.236114
# 10   Ceftamin          0                45.000000
# 11   Ceftamin          5                46.503051
# 12   Ceftamin         10                48.285125
# 13   Ceftamin         15                50.094055
# 14   Ceftamin         20                52.157049
# 15   Ceftamin         25                54.287674
# 16   Ceftamin         30                56.769517
# 17   Ceftamin         35                58.827548
# ...

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
sem_df = pd.DataFrame({'SE Tumor Volume (mm3)' : df.groupby(['Drug', 'Timepoint'])['Tumor Volume (mm3)'].sem()}).reset_index()


# Convert to DataFrame

# Preview DataFrame
sem_df
# Out:
#          Drug  Timepoint  SE Tumor Volume (mm3)
# 0   Capomulin          0               0.000000
# 1   Capomulin          5               0.448593
# 2   Capomulin         10               0.702684
# 3   Capomulin         15               0.838617
# 4   Capomulin         20               0.909731
# 5   Capomulin         25               0.881642
# 6   Capomulin         30               0.934460
# 7   Capomulin         35               1.052241
# 8   Capomulin         40               1.223608
# 9   Capomulin         45               1.223977
# 10   Ceftamin          0               0.000000
# 11   Ceftamin          5               0.164505
# 12   Ceftamin         10               0.236144
# 13   Ceftamin         15               0.332053
# 14   Ceftamin         20               0.359482
# 15   Ceftamin         25               0.439356
# 16   Ceftamin         30               0.490620
# 17   Ceftamin         35               0.692248
# 18   Ceftamin         40               0.708505
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames
mtv_df1_mi = pd.DataFrame({'Mean Tumor Volume (mm3)' : df.groupby(['Timepoint', 'Drug'])['Tumor Volume (mm3)'].mean()})

# Preview that Reformatting worked
trip = mtv_df1_mi.unstack(1)
trip
# Out:
#           Mean Tumor Volume (mm3)                                              \
# Drug                    Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol
# Timepoint
# 0                       45.000000  45.000000  45.000000  45.000000  45.000000
# 5                       44.266086  46.503051  47.062001  47.389175  46.796098
# 10                      43.084291  48.285125  49.403909  49.582269  48.694210
# 15                      42.064317  50.094055  51.296397  52.399974  50.933018
# 20                      40.716325  52.157049  53.197691  54.920935  53.644087
# 25                      39.939528  54.287674  55.715252  57.678982  56.731968
# 30                      38.769339  56.769517  58.299397  60.994507  59.559509
# 35                      37.816839  58.827548  60.742461  63.371686  62.685087
# 40                      36.958001  61.467895  63.162824  66.068580  65.600754
# 45                      36.236114  64.132421  65.755562  70.662958  69.265506
#
#
# ...

# %%
mtv_sem_df = pd.merge(mtv_df, sem_df, on=['Drug', 'Timepoint'])

fig, ax = plt.subplots()
markers = ['o', 'v', '<', '>', 'D', '8', 's', 'p', 'P', '*']
keys = []
for idx, (key, grp) in enumerate(mtv_sem_df.groupby(['Drug'])):
    ax = grp.plot(ax=ax, x='Timepoint', y='Mean Tumor Volume (mm3)', yerr='SE Tumor Volume (mm3)',
                 marker=markers[idx])
    keys.append(key)

ax.legend(keys, loc='best')
ax.grid('on')
ax.set_xlabel('Time (Days)')
ax.set_ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

Mean_met = pd.DataFrame({'Mean Metastatic sites':df.groupby(['Drug', 'Timepoint'])['Metastatic Sites'].mean()})




# Convert to DataFrame

# Preview DataFrame
Mean_met
# Out:
#                      Mean Metastatic sites
# Drug      Timepoint
# Capomulin 0                       0.000000
#           5                       0.160000
#           10                      0.320000
#           15                      0.375000
#           20                      0.652174
#           25                      0.818182
#           30                      1.090909
#           35                      1.181818
#           40                      1.380952
#           45                      1.476190
# Ceftamin  0                       0.000000
#           5                       0.380952
#           10                      0.600000
#           15                      0.789474
#           20                      1.111111
#           25                      1.500000
#           30                      1.937500
#           35                      2.071429
#           40                      2.357143
#           45                      2.692308
# ...

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
Mean_met_sem = pd.DataFrame({'SEM Metastatic sites':df.groupby(['Drug', 'Timepoint'])['Metastatic Sites'].sem()})
# Convert to DataFrame


# Preview DataFrame
Mean_met_sem
# Out:
#                      SEM Metastatic sites
# Drug      Timepoint
# Capomulin 0                      0.000000
#           5                      0.074833
#           10                     0.125433
#           15                     0.132048
#           20                     0.161621
#           25                     0.181818
#           30                     0.172944
#           35                     0.169496
#           40                     0.175610
#           45                     0.202591
# Ceftamin  0                      0.000000
#           5                      0.108588
#           10                     0.152177
#           15                     0.180625
#           20                     0.241034
#           25                     0.258831
#           30                     0.249479
#           35                     0.266526
#           40                     0.289128
#           45                     0.286101
# Infubinol 0                      0.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames
unstacked_data = Mean_met.unstack(0)
unstacked_data


# Preview that Reformatting worked
# Out:
#           Mean Metastatic sites                                          \
# Drug                  Capomulin  Ceftamin Infubinol  Ketapril  Naftisol
# Timepoint
# 0                      0.000000  0.000000  0.000000  0.000000  0.000000
# 5                      0.160000  0.380952  0.280000  0.304348  0.260870
# 10                     0.320000  0.600000  0.666667  0.590909  0.523810
# 15                     0.375000  0.789474  0.904762  0.842105  0.857143
# 20                     0.652174  1.111111  1.050000  1.210526  1.150000
# 25                     0.818182  1.500000  1.277778  1.631579  1.500000
# 30                     1.090909  1.937500  1.588235  2.055556  2.066667
# 35                     1.181818  2.071429  1.666667  2.294118  2.266667
# 40                     1.380952  2.357143  2.100000  2.733333  2.466667
# 45                     1.476190  2.692308  2.111111  3.363636  2.538462
#
#
# Drug        Placebo  Propriva  Ramicane  Stelasyn Zoniferol
# Timepoint
# ...

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

mean_sem_df = pd.merge(Mean_met, Mean_met_sem, on=['Drug','Timepoint'])


if True:
    fig, ax = plt.subplots()
    markers = ['o', 'v', '<', '>', 'D', '8', 's', 'p', 'P', 'z']
    keys = []
    for idx, (key, grp) in enumerate(mean_sem_df.groupby(['Drug'])):
        ax = grp.plot(ax=ax, x= 'Timepoint', y= mean_sem_df['Mean Metastatic sites'], yerr= mean_sem_df['SEM Metastatic sites'],
                     marker=markers[idx])
        keys.append(key)

    ax.legend(keys, loc='best')
    ax.grid('on')
    ax.set_xlabel('Time (Days)')
    ax.set_ylabel('Tumor Volume (mm3)')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timepoint'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-df0a72a64354> in <module>()
# ...

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)\

#count =  pd.DataFrame({'Mouse Count' : df.groupby(['Drug', 'Timepoint'])}.count()

#df.groupby(['Drug', 'Timepoint'])['Mouse ID'].count().reset_index()

m_cnt_df = pd.DataFrame({'Mouse Count': df.groupby(['Drug', 'Timepoint']).size()})
m_cnt_df

# Convert to DataFrame

# Preview DataFrame
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23
#           25                  22
#           30                  22
#           35                  22
#           40                  21
#           45                  21
# Ceftamin  0                   25
#           5                   21
#           10                  20
#           15                  19
#           20                  18
#           25                  18
#           30                  16
#           35                  14
#           40                  14
#           45                  13
# Infubinol 0                   25
#           5                   25
#           10                  21
#           15                  21
#           20                  20
#           25                  18
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames

m_cnt_df1 = m_cnt_df.unstack(0)

m_cnt_df1



# Preview the Data Frame
# Out:
#           Mouse Count                                                        \
# Drug        Capomulin Ceftamin Infubinol Ketapril Naftisol Placebo Propriva
# Timepoint
# 0                  25       25        25       25       25      25       26
# 5                  25       21        25       23       23      24       25
# 10                 25       20        21       22       21      24       23
# 15                 24       19        21       19       21      20       17
# 20                 23       18        20       19       20      19       17
# 25                 22       18        18       19       18      17       14
# 30                 22       16        17       18       15      15       13
# 35                 22       14        12       17       15      14       10
# 40                 21       14        10       15       15      12        9
# 45                 21       13         9       11       13      11        7
#
#
# Drug      Ramicane Stelasyn Zoniferol
# ...

# %%
# Generate the Plot (Accounting for percentages)
from functools import reduce
c_max = list(m_cnt_df1.ix[0, :])
cols = []
for idx, c in enumerate(m_cnt_df1):
    cols.append(m_cnt_df1[c].apply(lambda x: x*100/c_max[idx]).reset_index())
m_percent = reduce(lambda x, y: pd.merge(x, y, on='Timepoint'), cols)
m_percent
    
# Save the Figure

# Show the Figure
# Out:
#   Timepoint Mouse Count                                               \
#               Capomulin Ceftamin Infubinol Ketapril Naftisol Placebo
# 0         0       100.0    100.0     100.0    100.0    100.0   100.0
# 1         5       100.0     84.0     100.0     92.0     92.0    96.0
# 2        10       100.0     80.0      84.0     88.0     84.0    96.0
# 3        15        96.0     76.0      84.0     76.0     84.0    80.0
# 4        20        92.0     72.0      80.0     76.0     80.0    76.0
# 5        25        88.0     72.0      72.0     76.0     72.0    68.0
# 6        30        88.0     64.0      68.0     72.0     60.0    60.0
# 7        35        88.0     56.0      48.0     68.0     60.0    56.0
# 8        40        84.0     56.0      40.0     60.0     60.0    48.0
# 9        45        84.0     52.0      36.0     44.0     52.0    44.0
#
#
#      Propriva Ramicane    Stelasyn Zoniferol
# 0  100.000000    100.0  100.000000     100.0
# 1   96.153846    100.0   96.153846      96.0
# ...

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
pc = pd.DataFrame({'Percentage Change' : df.groupby(['Drug', 'Timepoint']).pct_change()})
#pc= df.groupby(['Timepoint', 'Drug'])['Tumor Volume (mm3)'].pct_change()
pc
# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()
